# %% [markdown]
# # make mass comparison plot for paper

# %%
#import functions from module
import sys
sys.path.append('/Users/fardila/Documents/GitHub/HSC_vs_hydro/')
from functions import *
# Out:
#       +------------------------------------------------------------+
#       |       Space Telescope Science Data Analysis System         |
#       |                   STSDAS Version 3.18.3                    |
#       |                                                            |
#       |   Space Telescope Science Institute, Baltimore, Maryland   |
#       |   Copyright (C) 2014 Association of Universities for       |
#       |            Research in Astronomy, Inc.(AURA)               |
#       |       See stsdas$copyright.stsdas for terms of use.        |
#       |         For help, send e-mail to help@stsci.edu            |
#       |                                                            |
#       +------------------------------------------------------------+
# stsdas/:
#  analysis/      examples        hst_calib/      sobsolete/
#  contrib/       fitsio/         playpen/        toolbox/
#  describe       graphics/       problems
# isophote/:
# ...

# %% [markdown]
# ## get masses from pickels

# %%
illustris_masses_quick = load_pkl('/Users/fardila/Documents/GitHub/HSC_vs_hydro/Data/Illustris/Illustris_masses_quick.pkl')
illustris_masses_highres = load_pkl('/Users/fardila/Documents/GitHub/HSC_vs_hydro/Data/Illustris/Illustris_masses_highres.pkl')

# %% [markdown]
# ## PLOTS

# %%
fig=plt.figure(figsize=[15,25])
ax1=plt.subplot(511)
ax2=plt.subplot(512)
ax3=plt.subplot(513)
ax4=plt.subplot(514)
ax5=plt.subplot(515)


ax1.scatter(illustris_masses_quick['m_cat'], illustris_masses_quick['m_cat'] - illustris_masses_quick['m_post'],
            c=illustris_color, label='quick: large physical size, lower resolution', alpha=0.5)
# ax1.scatter(illustris_masses_highres['m_cat'], illustris_masses_highres['m_cat'] - illustris_masses_highres['m_post'], c='r',
#            label= 'highres', alpha=0.5)
# ax1.plot(xs, illustris_diff_cat_post_line(xs), c=u'#1f77b4')
ax1.axhline(0,c="k",linewidth=2,linestyle='--')
# ax1.text(12, 0.05,'linear params: ' + str(illustris_diff_cat_post_params), fontsize=15)
ax1.set_ylabel(r'$M_{\star}^{\mathrm{cat}}$ - $M_{\star}^{\mathrm{post}}$', fontsize=30)

ax2.scatter(illustris_masses_quick['m_cat'], illustris_masses_quick['m_cat'] - illustris_masses_quick['m_post_icl'],
            c=illustris_color, alpha=0.5)
# ax2.scatter(illustris_masses_highres['m_cat'], illustris_masses_highres['m_cat'] - illustris_masses_highres['m_post_icl'], c='r', 
#             alpha=0.5)
# ax2.plot(xs, illustris_diff_cat_post_icl_line(xs), c=u'#1f77b4')
ax2.axhline(0,c="k",linewidth=2,linestyle='--')
# ax2.text(12, 0.05,'linear params: ' + str(illustris_diff_cat_post_icl_params), fontsize=15)
ax2.set_ylabel(r'$M_{\star}^{\mathrm{cat}}$ - $M_{\star}^{\mathrm{post, diffuse}}$ ', fontsize=30)

# ax3.scatter(illustris_masses_quick['m_cat'], illustris_masses_quick['m_cat'] - illustris_masses_quick['m_1d_100'], c=u'#1f77b4')
ax3.scatter(illustris_masses_highres['m_cat'], illustris_masses_highres['m_cat'] - illustris_masses_highres['m_1d_100'],
            c=illustris_color, alpha=0.5)
# ax3.plot(xs, illustris_diff_cat_1d100_line(xs), c=u'#1f77b4')
ax3.axhline(0, c="k",linewidth=2, linestyle='--')
# ax3.text(12, 0.05,'linear params: ' + str(illustris_diff_cat_1d100_params), fontsize=15)
ax3.set_ylabel(r'$M_{\star}^{\mathrm{cat}}$ - $M_{\star}^{\mathrm{1d, 100}}$ ', fontsize=30)

# ax4.scatter(illustris_masses_quick['m_cat'], illustris_masses_quick['m_2d_100'] - illustris_masses_quick['m_1d_100'], c=u'#1f77b4')
ax4.scatter(illustris_masses_highres['m_cat'], illustris_masses_highres['m_2d_100'] - illustris_masses_highres['m_1d_100'],
            c=illustris_color, alpha=0.5)
# ax4.plot(xs, illustris_diff_2d_1d_30_line(xs), c=u'#1f77b4')
ax4.axhline(0,c="k",linewidth=2,linestyle='--')
# ax4.text(12, 0.05,'linear params: ' + str(illustris_diff_2d_1d_30_params), fontsize=15)
ax4.set_ylabel(r'$M_{\star}^{\mathrm{2d, 100}}$ - $M_{\star}^{\mathrm{1d, 100}}$ ', fontsize=30)

# ax5.scatter(illustris_masses_quick['m_cat'], illustris_masses_quick['m_cat'] - illustris_masses_quick['extrapolated_m_300'], c=u'#1f77b4')
ax5.scatter(illustris_masses_highres['m_cat'], illustris_masses_highres['m_cat'] - illustris_masses_highres['extrapolated_m_300'],
            c=illustris_color, alpha=0.5)
# ax5.plot(xs, illustris_diff_cat_1dextrap_line(xs), c=u'#1f77b4')
ax5.axhline(0,c="k",linewidth=2,linestyle='--')
# ax5.text(12, 0.05,'linear params: ' + str(illustris_diff_cat_1dextrap_params), fontsize=15)
ax5.set_ylabel(r'$M_{\star}^{\mathrm{cat}}$ - $M_{\star}^{\mathrm{extrap, 300}}$ ', fontsize=30)


# ax1.legend(fontsize=20)

ax5.set_xlabel('$M_{\star}^{\mathrm{cat}}$', fontsize=40)
ax1.set_title('Illustris', fontsize=45)
#plt.tight_layout()

for ax in [ax1,ax2,ax3,ax4,ax5]:
    ax.set_ylim([-0.25,0.25])
    
# fig.savefig('/Users/fardila/Documents/GitHub/HSC_vs_hydro/Plots/mass_differences_Illustris.pdf',
#             dpi=100, format='pdf', bbox_inches='tight')

# %% [markdown]
# # TNG

# %%
tng_masses_quick = load_pkl('/Users/fardila/Documents/GitHub/HSC_vs_hydro/Data/TNG/TNG_masses_quick.pkl')
tng_masses_highres = load_pkl('/Users/fardila/Documents/GitHub/HSC_vs_hydro/Data/TNG/TNG_masses_highres.pkl')

# %%
fig=plt.figure(figsize=[15,25])
ax1=plt.subplot(511)
ax2=plt.subplot(512)
ax3=plt.subplot(513)
ax4=plt.subplot(514)
ax5=plt.subplot(515)


ax1.scatter(tng_masses_quick['m_cat'], tng_masses_quick['m_cat'] - tng_masses_quick['m_post'], c=tng_color,
            label='quick: large physical size, lower resolution', alpha=0.5)
# ax1.scatter(tng_masses_highres['m_cat'], tng_masses_highres['m_cat'] - tng_masses_highres['m_post'], c='r',
#            label= 'highres', alpha=0.5)
# ax1.plot(xs, tng_diff_cat_post_line(xs), c=u'#1f77b4')
ax1.axhline(0,c="k",linewidth=2,linestyle='--')
# ax1.text(12, 0.05,'linear params: ' + str(tng_diff_cat_post_params), fontsize=15)
ax1.set_ylabel(r'$M_{\star}^{\mathrm{cat}}$ - $M_{\star}^{\mathrm{post}}$', fontsize=30)

ax2.scatter(tng_masses_quick['m_cat'], tng_masses_quick['m_cat'] - tng_masses_quick['m_post_icl'], c=tng_color,
           alpha=0.5)
# ax2.scatter(tng_masses_highres['m_cat'], tng_masses_highres['m_cat'] - tng_masses_highres['m_post_icl'], c='r', 
#             alpha=0.5)
# ax2.plot(xs, tng_diff_cat_post_icl_line(xs), c=u'#1f77b4')
ax2.axhline(0,c="k",linewidth=2,linestyle='--')
# ax2.text(12, 0.05,'linear params: ' + str(tng_diff_cat_post_icl_params), fontsize=15)
ax2.set_ylabel(r'$M_{\star}^{\mathrm{cat}}$ - $M_{\star}^{\mathrm{post, diffuse}}$ ', fontsize=30)

# ax3.scatter(tng_masses_quick['m_cat'], tng_masses_quick['m_cat'] - tng_masses_quick['m_1d_100'], c=u'#1f77b4')
ax3.scatter(tng_masses_highres['m_cat'], tng_masses_highres['m_cat'] - tng_masses_highres['m_1d_100'], c=tng_color,
           alpha=0.5)
# ax3.plot(xs, tng_diff_cat_1d100_line(xs), c=u'#1f77b4')
ax3.axhline(0, c="k",linewidth=2, linestyle='--')
# ax3.text(12, 0.05,'linear params: ' + str(tng_diff_cat_1d100_params), fontsize=15)
ax3.set_ylabel(r'$M_{\star}^{\mathrm{cat}}$ - $M_{\star}^{\mathrm{1d, 100}}$ ', fontsize=30)

# ax4.scatter(tng_masses_quick['m_cat'], tng_masses_quick['m_2d_100'] - tng_masses_quick['m_1d_100'], c=u'#1f77b4')
ax4.scatter(tng_masses_highres['m_cat'], tng_masses_highres['m_2d_100'] - tng_masses_highres['m_1d_100'], c=tng_color,
           alpha=0.5)
# ax4.plot(xs, tng_diff_2d_1d_30_line(xs), c=u'#1f77b4')
ax4.axhline(0,c="k",linewidth=2,linestyle='--')
# ax4.text(12, 0.05,'linear params: ' + str(tng_diff_2d_1d_30_params), fontsize=15)
ax4.set_ylabel(r'$M_{\star}^{\mathrm{2d, 100}}$ - $M_{\star}^{\mathrm{1d, 100}}$ ', fontsize=30)

# ax5.scatter(tng_masses_quick['m_cat'], tng_masses_quick['m_cat'] - tng_masses_quick['extrapolated_m_300'], c=u'#1f77b4')
ax5.scatter(tng_masses_highres['m_cat'], tng_masses_highres['m_cat'] - tng_masses_highres['extrapolated_m_300'],
            c=tng_color,
           alpha=0.5)
# ax5.plot(xs, tng_diff_cat_1dextrap_line(xs), c=u'#1f77b4')
ax5.axhline(0,c="k",linewidth=2,linestyle='--')
# ax5.text(12, 0.05,'linear params: ' + str(tng_diff_cat_1dextrap_params), fontsize=15)
ax5.set_ylabel(r'$M_{\star}^{\mathrm{cat}}$ - $M_{\star}^{\mathrm{extrap, 300}}$ ', fontsize=30)


# ax1.legend(fontsize=20)

ax5.set_xlabel('$M_{\star}^{\mathrm{cat}}$', fontsize=40)
ax1.set_title('TNG', fontsize=45)
#plt.tight_layout()

for ax in [ax1,ax2,ax3,ax4,ax5]:
    ax.set_ylim([-0.25,0.25])
    
# fig.savefig('/Users/fardila/Documents/GitHub/HSC_vs_hydro/Plots/mass_differences_TNG.pdf',
#             dpi=100, format='pdf', bbox_inches='tight')

# %% [markdown]
# # plots for paper

# %%
fig=plt.figure(figsize=(12, 12))
gs = gridspec.GridSpec(3, 1,wspace=0.0,hspace=0.05)
ax1 = plt.subplot(gs[0, 0])
ax2 = plt.subplot(gs[1, 0])
ax3 = plt.subplot(gs[2, 0])


ax1.scatter(illustris_masses_highres['m_cat'], illustris_masses_highres['m_cat'] - illustris_masses_highres['m_1d_100'], c=illustris_color,
           alpha=0.5)
# ax3.plot(xs, illustris_diff_cat_1d100_line(xs), c=u'#1f77b4')
ax1.axhline(0, c="k",linewidth=2, linestyle='--')
# ax3.text(12, 0.05,'linear params: ' + str(illustris_diff_cat_1d100_params), fontsize=15)
ax1.set_ylabel(r'$M_{\star}^{\mathrm{cat}}$ - $M_{\star}^{\mathrm{1d, 100}}$ ', fontsize=30)

ax2.scatter(illustris_masses_highres['m_cat'], illustris_masses_highres['m_2d_100'] - illustris_masses_highres['m_1d_100'], c=illustris_color,
           alpha=0.5)
# ax4.plot(xs, illustris_diff_2d_1d_30_line(xs), c=u'#1f77b4')
ax2.axhline(0,c="k",linewidth=2,linestyle='--')
# ax4.text(12, 0.05,'linear params: ' + str(illustris_diff_2d_1d_30_params), fontsize=15)
ax2.set_ylabel(r'$M_{\star}^{\mathrm{2d, 100}}$ - $M_{\star}^{\mathrm{1d, 100}}$ ', fontsize=30)

ax3.scatter(illustris_masses_highres['m_cat'], illustris_masses_highres['m_cat'] - illustris_masses_highres['extrapolated_m_300'],
            c=illustris_color, alpha=0.5)
# ax5.plot(xs, illustris_diff_cat_1dextrap_line(xs), c=u'#1f77b4')
ax3.axhline(0,c="k",linewidth=2,linestyle='--')
# ax5.text(12, 0.05,'linear params: ' + str(illustris_diff_cat_1dextrap_params), fontsize=15)
ax3.set_ylabel(r'$M_{\star}^{\mathrm{cat}}$ - $M_{\star}^{\mathrm{extrap, 300}}$ ', fontsize=30)


# ax1.legend(fontsize=20)


ax1.tick_params(axis='both', which='both', direction = 'in', labelsize=20)
ax2.tick_params(axis='both', which='both', direction = 'in', labelsize=20)
ax3.tick_params(axis='both', which='major', direction = 'in', labelsize=20)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax2.get_xticklabels(), visible=False)

ax3.set_xlabel('$M_{\star}^{\mathrm{cat}}$', fontsize=40, labelpad = 15)
# ax1.set_title('Illustris', fontsize=45)
# plt.tight_layout(pad=0, h_pad=0, w_pad=0)

for ax in [ax1,ax2,ax3]:
    ax.set_ylim([-0.25,0.25])
    
fig.savefig('/Users/fardila/Documents/GitHub/HSC_vs_hydro/Plots/mass_differences_Illustris.pdf',
            dpi=100, format='pdf', bbox_inches='tight')

# %%
fig=plt.figure(figsize=(12, 12))
gs = gridspec.GridSpec(3, 1,wspace=0.0,hspace=0.05)
ax1 = plt.subplot(gs[0, 0])
ax2 = plt.subplot(gs[1, 0])
ax3 = plt.subplot(gs[2, 0])


ax1.scatter(tng_masses_highres['m_cat'], tng_masses_highres['m_cat'] - tng_masses_highres['m_1d_100'], c=tng_color,
           alpha=0.5)
# ax3.plot(xs, tng_diff_cat_1d100_line(xs), c=u'#1f77b4')
ax1.axhline(0, c="k",linewidth=2, linestyle='--')
# ax3.text(12, 0.05,'linear params: ' + str(tng_diff_cat_1d100_params), fontsize=15)
ax1.set_ylabel(r'$M_{\star}^{\mathrm{cat}}$ - $M_{\star}^{\mathrm{1d, 100}}$ ', fontsize=30)

ax2.scatter(tng_masses_highres['m_cat'], tng_masses_highres['m_2d_100'] - tng_masses_highres['m_1d_100'], c=tng_color,
           alpha=0.5)
# ax4.plot(xs, tng_diff_2d_1d_30_line(xs), c=u'#1f77b4')
ax2.axhline(0,c="k",linewidth=2,linestyle='--')
# ax4.text(12, 0.05,'linear params: ' + str(tng_diff_2d_1d_30_params), fontsize=15)
ax2.set_ylabel(r'$M_{\star}^{\mathrm{2d, 100}}$ - $M_{\star}^{\mathrm{1d, 100}}$ ', fontsize=30)

ax3.scatter(tng_masses_highres['m_cat'], tng_masses_highres['m_cat'] - tng_masses_highres['extrapolated_m_300'],
            c=tng_color, alpha=0.5)
# ax5.plot(xs, tng_diff_cat_1dextrap_line(xs), c=u'#1f77b4')
ax3.axhline(0,c="k",linewidth=2,linestyle='--')
# ax5.text(12, 0.05,'linear params: ' + str(tng_diff_cat_1dextrap_params), fontsize=15)
ax3.set_ylabel(r'$M_{\star}^{\mathrm{cat}}$ - $M_{\star}^{\mathrm{extrap, 300}}$ ', fontsize=30)


# ax1.legend(fontsize=20)


ax1.tick_params(axis='both', which='both', direction = 'in', labelsize=20)
ax2.tick_params(axis='both', which='both', direction = 'in', labelsize=20)
ax3.tick_params(axis='both', which='major', direction = 'in', labelsize=20)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax2.get_xticklabels(), visible=False)

ax3.set_xlabel('$M_{\star}^{\mathrm{cat}}$', fontsize=40, labelpad = 15)
# ax1.set_title('TNG', fontsize=45)
# plt.tight_layout(pad=0, h_pad=0, w_pad=0)

for ax in [ax1,ax2,ax3]:
    ax.set_ylim([-0.25,0.25])
    
fig.savefig('/Users/fardila/Documents/GitHub/HSC_vs_hydro/Plots/mass_differences_TNG.pdf',
            dpi=100, format='pdf', bbox_inches='tight')

# %% [markdown]
# ## Updated plot

# %%
fig=plt.figure(figsize=(12, 12))
gs = gridspec.GridSpec(4, 1,wspace=0,hspace=0.05)
ax1 = plt.subplot(gs[0, 0])
ax2 = plt.subplot(gs[1, 0])
ax3 = plt.subplot(gs[2, 0])
ax4 = plt.subplot(gs[3, 0])

ax1.scatter(tng_masses_highres['m_cat'], tng_masses_highres['m_2d_100'] - tng_masses_highres['m_1d_100'], c=tng_color,
           alpha=0.5, zorder=2)
# ax4.plot(xs, tng_diff_2d_1d_30_line(xs), c=u'#1f77b4')
ax1.axhline(0,c="k",linewidth=2,linestyle='--', zorder=1)
ax1.axhline(np.mean(tng_masses_highres['m_2d_100'] - tng_masses_highres['m_1d_100']),linewidth=2,linestyle=':')
ax1.text(12.53, np.mean(tng_masses_highres['m_2d_100'] - tng_masses_highres['m_1d_100']),
         str(round(np.mean(tng_masses_highres['m_2d_100'] - tng_masses_highres['m_1d_100']),2)),
         size=25, color=tng_color)
ax1.set_ylabel(r'$\log\left(\frac{M_{\star}^{\mathrm{2d, 100}}}{M_{\star}^{\mathrm{1d, 100}}}\right)$ ', fontsize=30)

ax2.scatter(tng_masses_highres['m_cat'], tng_masses_highres['m_cat'] - tng_masses_highres['m_1d_100'], c=tng_color,
           alpha=0.5, zorder=2)
ax2.axhline(0, c="k",linewidth=2, linestyle='--', zorder=1)
ax2.axhline(np.mean(tng_masses_highres['m_cat'] - tng_masses_highres['m_1d_100']),linewidth=2,linestyle=':')
ax2.text(12.53, np.mean(tng_masses_highres['m_cat'] - tng_masses_highres['m_1d_100']),
         str(round(np.mean(tng_masses_highres['m_cat'] - tng_masses_highres['m_1d_100']),2)),
         size=25, color=tng_color)
ax2.set_ylabel(r'$\log\left(\frac{M_{\star}^{\mathrm{cat}}}{M_{\star}^{\mathrm{1d, 100}}}\right)$ ', fontsize=30)

ax3.scatter(tng_masses_highres['m_cat'], tng_masses_highres['m_cat'] - tng_masses_highres['m_1d_800'], c=tng_color,
           alpha=0.5, zorder=2)
ax3.axhline(0, c="k",linewidth=2, linestyle='--', zorder=1)
ax3.axhline(np.mean(tng_masses_highres['m_cat'] - tng_masses_highres['m_1d_800']),linewidth=2,linestyle=':')
ax3.text(12.53, np.mean(tng_masses_highres['m_cat'] - tng_masses_highres['m_1d_800']),
         str(round(np.mean(tng_masses_highres['m_cat'] - tng_masses_highres['m_1d_800']),2)),
         size=25, color=tng_color)
ax3.set_ylabel(r'$\log\left(\frac{M_{\star}^{\mathrm{cat}}}{M_{\star}^{\mathrm{1d, 800}}}\right)$ ', fontsize=30)

ax4.scatter(tng_masses_highres['m_cat'], tng_masses_highres['m_cat'] - tng_masses_highres['extrapolated_m_800'],
            c=tng_color, alpha=0.5, zorder=2)
ax4.axhline(0,c="k",linewidth=2,linestyle='--', zorder=1)
ax4.axhline(np.mean(tng_masses_highres['m_cat'] - tng_masses_highres['extrapolated_m_800']),linewidth=2,linestyle=':')
ax4.text(12.53, np.mean(tng_masses_highres['m_cat'] - tng_masses_highres['extrapolated_m_800']),
         str(round(np.mean(tng_masses_highres['m_cat'] - tng_masses_highres['extrapolated_m_800']),2)),
         size=25, color=tng_color)
ax4.set_ylabel(r'$\log\left(\frac{M_{\star}^{\mathrm{cat}}}{M_{\star}^{\mathrm{extrap, 800}}}\right)$ ', fontsize=30)


ax1.tick_params(axis='both', which='both', direction = 'in', labelsize=25)
ax2.tick_params(axis='both', which='both', direction = 'in', labelsize=25)
ax3.tick_params(axis='both', which='both', direction = 'in', labelsize=25)
ax4.tick_params(axis='both', which='major', direction = 'in', labelsize=25)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax3.get_xticklabels(), visible=False)

ax4.set_xlabel('$M_{\star}^{\mathrm{cat}}$', fontsize=40, labelpad = 15)
# ax1.set_title('TNG', fontsize=45)
plt.tight_layout(pad=100)

for ax in [ax1,ax2,ax3,ax4]:
    ax.set_ylim([-0.25,0.25])

plt.subplots_adjust(left=0.1, right=1)
fig.savefig('/Users/fardila/Documents/GitHub/HSC_vs_hydro/Plots/mass_differences_TNG.pdf',
        dpi=100, format='pdf', bbox_inches='tight')

# %% [markdown]
# ## just 2d vs 1d

# %%
fig=plt.figure(figsize=(12, 12))
ax1 = plt.subplot()

ax1.scatter(tng_masses_highres['m_cat'], tng_masses_highres['m_2d_100'] - tng_masses_highres['m_1d_100'], c=tng_color,
           alpha=0.5, s=80, zorder=2)
# ax4.plot(xs, tng_diff_2d_1d_30_line(xs), c=u'#1f77b4')
ax1.axhline(0,c="k",linewidth=2,linestyle='--', zorder=0)
ax1.axhline(np.mean(tng_masses_highres['m_2d_100'] - tng_masses_highres['m_1d_100']),linewidth=2,linestyle=':')
ax1.text(12.53, np.mean(tng_masses_highres['m_2d_100'] - tng_masses_highres['m_1d_100']),
         str(round(np.mean(tng_masses_highres['m_2d_100'] - tng_masses_highres['m_1d_100']),3)),
         size=25, color=tng_color)
ax1.set_ylabel(r'$\log\left(\frac{M_{\star}^{\mathrm{2d, 100}}}{M_{\star}^{\mathrm{1d, 100}}}\right)$', fontsize=40)


plt.xlabel(r'$M_{\star}^{\mathrm{cat}}$', fontsize=40)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
ax1.set_ylim([-0.1,0.1])

# plt.legend(loc='lower right', fontsize=35)

plt.savefig('/Users/fardila/Documents/GitHub/HSC_vs_hydro/Plots/2d-1d_masses_TNG.pdf',
        dpi=100, format='pdf', bbox_inches='tight')

# %%
print('Mean \t STD')
print("2D-1D", np.mean(tng_masses_highres['m_2d_100'] - tng_masses_highres['m_1d_100']),
      np.std(tng_masses_highres['m_2d_100'] - tng_masses_highres['m_1d_100']))
print("cat-1D_100", np.mean(tng_masses_highres['m_cat'] - tng_masses_highres['m_1d_100']),
      np.std(tng_masses_highres['m_cat'] - tng_masses_highres['m_1d_100']))
print("cat-1D_800", np.mean(tng_masses_highres['m_cat'] - tng_masses_highres['m_1d_800']),
      np.std(tng_masses_highres['m_cat'] - tng_masses_highres['m_1d_800']))
print("cat-extrap_800", np.mean(tng_masses_highres['m_cat'] - tng_masses_highres['extrapolated_m_800']),
      np.std(tng_masses_highres['m_cat'] - tng_masses_highres['extrapolated_m_800']))
print("cat-extrap_300", np.mean(tng_masses_highres['m_cat'] - tng_masses_highres['extrapolated_m_300']),
      np.std(tng_masses_highres['m_cat'] - tng_masses_highres['extrapolated_m_300']))
# Out:
# Mean 	 STD
# ('2D-1D', 0.010890815373056587, 0.023316229739171496)
# ('cat-1D_100', 0.05909076512067752, 0.04289634322578174)
# ('cat-1D_800', 0.022596614796804852, 0.029706417269974274)
# ('cat-extrap_800', -0.040733663331465934, 0.06202876707417393)
# ('cat-extrap_300', -0.005232145692877515, 0.03707270024344907)
